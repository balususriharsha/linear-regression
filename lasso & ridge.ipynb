# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import seaborn as sns

# %%
x1= np.random.uniform(1,10,100)
y1=5*x1+3+np.random.normal(0,1,100)

x2= np.random.uniform(7,9,30)
y2=8*x2+10+np.random.normal(0,1,30)

# %%
df= pd.DataFrame(columns=['x','y'])

# %%
df['x']=list(x1)+list(x2)
df['y']=list(y1)+list(y2)

# %%
plt.scatter(df['x'],df['y'])

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
model=reg.fit(df[['x']],df[['y']])

# %%
pred=model.predict(df[['x']])

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],pred)

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
model2=Ridge(alpha=500)
model2.fit(df[['x']],df[['y']])
# Out:
# Ridge(alpha=500, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
pred1=model2.predict(df[['x']])

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],pred1)
plt.plot(df['x'],pred,color='black')

# %%
model1=Lasso(alpha=10)
model1.fit(df[['x']],df[['y']])
pred2=model1.predict(df[['x']])

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],pred2,color='brown')#lasso
plt.plot(df['x'],pred1,color='orange')#ridge
plt.plot(df['x'],pred,color='black')#linear

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],pred2,color='brown')#lasso

# %%
from sklearn.linear_model import RANSACRegressor

# %%
model4=RANSACRegressor()
model4.fit(df[['x']],df[['y']])
pred3=model4.predict(df[['x']])

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],pred2,color='brown')#lasso
plt.plot(df['x'],pred1,color='orange')#ridge
plt.plot(df['x'],pred,color='black')#linear
plt.plot(df['x'],pred3,color='yellow')#ransac
