# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import ProbPlot

# %%
plt.style.use('seaborn') # pretty matplotlib plots
plt.rc('font', size=14)
plt.rc('figure', titlesize=18)
plt.rc('axes', labelsize=15)
plt.rc('axes', titlesize=18)

# %%
from sklearn.datasets import load_diabetes
diabetes =load_diabetes()

x = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
y = pd.DataFrame(diabetes.target)
x
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7    0.063504  0.050680 -0.001895  0.066630  0.090620  0.108914  0.022869
# 8    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9   -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 11   0.027178  0.050680  0.017506 -0.033214 -0.007073  0.045972 -0.065491
# ...

# %%
x.shape
# Out:
# (442, 10)

# %%
y
# Out:
#          0
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# 5     97.0
# 6    138.0
# 7     63.0
# 8    110.0
# 9    310.0
# 10   101.0
# 11    69.0
# 12   179.0
# 13   185.0
# 14   118.0
# 15   171.0
# 16   166.0
# 17   144.0
# 18    97.0
# 19   168.0
# 20    68.0
# 21    49.0
# 22    68.0
# 23   245.0
# 24   184.0
# 25   202.0
# 26   137.0
# 27    85.0
# 28   131.0
# 29   283.0
# ..     ...
# 412  261.0
# 413  113.0
# 414  131.0
# 415  174.0
# 416  257.0
# 417   55.0
# 418   84.0
# 419   42.0
# 420  146.0
# 421  212.0
# 422  233.0
# 423   91.0
# 424  111.0
# 425  152.0
# 426  120.0
# 427   67.0
# 428  310.0
# 429   94.0
# 430  183.0
# 431   66.0
# 432  173.0
# 433   72.0
# 434   49.0
# 435   64.0
# 436   48.0
# 437  178.0
# 438  104.0
# 439  132.0
# 440  220.0
# 441   57.0
#
# [442 rows x 1 columns]

# %%
y.columns=['target']
y
# Out:
#      target
# 0     151.0
# 1      75.0
# 2     141.0
# 3     206.0
# 4     135.0
# 5      97.0
# 6     138.0
# 7      63.0
# 8     110.0
# 9     310.0
# 10    101.0
# 11     69.0
# 12    179.0
# 13    185.0
# 14    118.0
# 15    171.0
# 16    166.0
# 17    144.0
# 18     97.0
# 19    168.0
# 20     68.0
# 21     49.0
# 22     68.0
# 23    245.0
# 24    184.0
# 25    202.0
# 26    137.0
# 27     85.0
# 28    131.0
# 29    283.0
# ..      ...
# 412   261.0
# 413   113.0
# 414   131.0
# 415   174.0
# 416   257.0
# 417    55.0
# 418    84.0
# 419    42.0
# 420   146.0
# 421   212.0
# 422   233.0
# 423    91.0
# 424   111.0
# 425   152.0
# 426   120.0
# 427    67.0
# 428   310.0
# 429    94.0
# 430   183.0
# 431    66.0
# 432   173.0
# 433    72.0
# 434    49.0
# 435    64.0
# 436    48.0
# 437   178.0
# 438   104.0
# 439   132.0
# 440   220.0
# 441    57.0
#
# [442 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()

# %%
regr.fit(x_train,y_train)
y_pred=regr.predict(x_test)
print(y_pred)
# Out:
# [[241.84730258]
#  [250.12303941]
#  [164.96456549]
#  [119.11639346]
#  [188.23120303]
#  [260.56079379]
#  [113.07583812]
#  [190.54117538]
#  [151.8883747 ]
#  [236.50848375]
#  [168.76844138]
#  [180.52719713]
#  [109.16037049]
#  [ 90.20148392]
#  [244.73990469]
#  [ 90.58113696]
#  [152.51268196]
#  [ 66.97735025]
#  [ 98.0467335 ]
#  [215.39557064]
#  [197.70737206]
#  [160.9176914 ]
#  [162.88584001]
#  [158.25373793]
#  [202.44823294]
#  [168.46663088]
#  [119.87243699]
#  [ 83.05669211]
#  [189.9839726 ]
#  [163.02279586]
#  [177.07828326]
#  [ 82.6702699 ]
#  [144.53204953]
#  [146.07901596]
#  [141.73841253]
#  [195.18658206]
#  [164.18043648]
#  [189.14768927]
#  [128.13330927]
#  [206.12996392]
#  [ 82.64273523]
#  [164.94912645]
#  [144.46057692]
#  [182.0519825 ]
#  [178.41355601]
#  [ 72.5504089 ]
#  [142.69750371]
#  [140.43671531]
#  [121.75256103]
#  [233.70553551]
#  [162.07809758]
#  [ 76.90270416]
#  [155.68916375]
#  [156.64052259]
#  [238.11357481]
# ...

# %%
y_pred.shape
# Out:
# (111, 1)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('Mean square error: %.2f'% mean_squared_error(y_test,y_pred))
# Out:
# Mean square error: 3180.20

# %%
print('variance score:%.2f'%r2_score(y_test,y_pred))
# Out:
# variance score:0.36

# %%
print(regr.score(x_test,y_test))
# Out:
# 0.35940090989715534

# %%
print(regr.coef_)
# Out:
# [[ -43.26774487 -208.67053951  593.39797213  302.89814903 -560.27689824
#    261.47657106   -8.83343952  135.93715156  703.22658427   28.34844354]]

# %%
print(regr.intercept_)
# Out:
# [153.06798218]

# %%
df = pd.DataFrame({'actual':y_test['target'],'predict':y_pred.flatten()})

# %%
df
# Out:
#      actual     predict
# 362   321.0  241.847303
# 249   215.0  250.123039
# 271   127.0  164.964565
# 435    64.0  119.116393
# 400   175.0  188.231203
# 403   275.0  260.560794
# 12    179.0  113.075838
# 399   232.0  190.541175
# 198   142.0  151.888375
# 205    99.0  236.508484
# 78    252.0  168.768441
# 144   174.0  180.527197
# 298   129.0  109.160370
# 171    74.0   90.201484
# 268   264.0  244.739905
# 21     49.0   90.581137
# 194    86.0  152.512682
# 1      75.0   66.977350
# 10    101.0   98.046734
# 208   155.0  215.395571
# 76    170.0  197.707372
# 37    276.0  160.917691
# 388   110.0  162.885840
# 411   136.0  158.253738
# 289    68.0  202.448233
# 100   128.0  168.466631
# 261   103.0  119.872437
# 401    93.0   83.056692
# 319   191.0  189.983973
# 206   196.0  163.022796
# ..      ...         ...
# 96    150.0  208.853116
# 170    47.0   48.034047
# 113   297.0  206.619258
# 381   104.0   76.631627
# 213    49.0   92.706304
# 134   103.0  148.193218
# ...

# %%
df=pd.concat([x_test,df],axis=1)

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 362  0.019913  0.050680  0.104809  0.070073 -0.035968 -0.026679 -0.024993
# 249 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 271  0.038076  0.050680  0.008883  0.042530 -0.042848 -0.021042 -0.039719
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 400 -0.023677 -0.044642  0.045529  0.090730 -0.018080 -0.035447  0.070730
# 403 -0.020045 -0.044642  0.097264 -0.005671 -0.005697 -0.023861 -0.021311
# 12   0.016281 -0.044642 -0.028840 -0.009113 -0.004321 -0.009769  0.044958
# 399  0.059871  0.050680  0.022895  0.049415  0.016318  0.011838 -0.013948
# 198 -0.052738 -0.044642  0.054152 -0.026328 -0.055231 -0.033881 -0.013948
# 205 -0.030942 -0.044642  0.046607  0.014987 -0.016704 -0.047034  0.000779
# 78   0.005383 -0.044642 -0.057941 -0.022885 -0.067615 -0.068328 -0.054446
# 144  0.030811  0.050680  0.046607 -0.015999  0.020446  0.050669 -0.058127
# ...

# %%
df.to_csv('final diabaties.csv')

# %%
df['diff']=df['actual']-df['predict']

# %%
df['percent error']=df['diff']/df['actual']

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 362  0.019913  0.050680  0.104809  0.070073 -0.035968 -0.026679 -0.024993
# 249 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 271  0.038076  0.050680  0.008883  0.042530 -0.042848 -0.021042 -0.039719
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 400 -0.023677 -0.044642  0.045529  0.090730 -0.018080 -0.035447  0.070730
# 403 -0.020045 -0.044642  0.097264 -0.005671 -0.005697 -0.023861 -0.021311
# 12   0.016281 -0.044642 -0.028840 -0.009113 -0.004321 -0.009769  0.044958
# 399  0.059871  0.050680  0.022895  0.049415  0.016318  0.011838 -0.013948
# 198 -0.052738 -0.044642  0.054152 -0.026328 -0.055231 -0.033881 -0.013948
# 205 -0.030942 -0.044642  0.046607  0.014987 -0.016704 -0.047034  0.000779
# 78   0.005383 -0.044642 -0.057941 -0.022885 -0.067615 -0.068328 -0.054446
# 144  0.030811  0.050680  0.046607 -0.015999  0.020446  0.050669 -0.058127
# ...

# %%
print(diabetes.DESCR())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-92276bcbf870> in <module>
# ----> 1 print(diabetes.DESCR())
#
# TypeError: 'str' object is not callable
